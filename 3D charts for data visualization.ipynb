# %% [markdown]
# ## 3D charts for data visualization
# Hands-on activity with Python
# Editor: Saeid SHARIFY
# Date: 2021/08/08

# %% [markdown]
# #### Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm

# %matplotlib inline

# %% [markdown]
# #### Minimise // the function we use
# $f(x, y) = \frac{1}{3^{-x^2 - y^2} + 1}$
#
#
# We can also simplify representing this function to:
# $f(x, y) = \frac{1}{r +1}$ where $r$ is $3^{-x^2 - y^2}$
#
# Now lets write the Python code to express this function.

# %%
# writing the function
def f(x, y):
    r = 3**(-x**2 - y**2)
    return 1 / (r + 1)

# %% [markdown]
# Now lets create a chart with this function.

# %%
# as usual with charts, we need to generate some data first
x_array = np.linspace(start=-2, stop=2, num=200) # type : numpy.ndarray
y_array = np.linspace(start=-2, stop=2, num=200) # type : numpy.ndarray

print('Shape of X array', x_array.shape)
# 1 dimension vector (200,)
# Out:
# Shape of X array (200,)

# %%
# setting up 3D plot
fig_object = plt.figure(figsize=[16,9])
# getting the axis from the figure using gca. function
axx = fig_object.gca(projection='3d')

# the three inputs of .plot_surface(x,y,z) needs to be 2d arrays
x_array, y_array = np.meshgrid(x_array,y_array)
# print('After meshgrid', x_array.shape)

# add some labels to axis
axx.set_xlabel('X', fontsize = 14)
axx.set_ylabel('Y', fontsize = 14)
axx.set_zlabel('f(x,y) - cost', fontsize = 14)

# adding color to the cost changes using color map cm package
axx.plot_surface(x_array, y_array, f(x_array, y_array), cmap = cm.coolwarm, alpha = 0.5)
plt.show()
# Out:
# /tmp/ipykernel_7021/3096216195.py:4: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   axx = fig_object.gca(projection='3d')
