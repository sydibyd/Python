# %% [markdown]
# ## Divergence and Overflow
# Editor: Saeid Sharify
# Date: 2021/10/10

# %% [markdown]
# #### Notebook import and packages

# %%
import matplotlib.pyplot as ppl
import numpy as np

# %matplotlib inline

# %% [markdown]
# #### Divergence and Overflow
# $h(x) = x^5 - 2x^4 + 2$

# %%
# generate some data
X_3 = np.linspace(start=-2.5, stop=2.5, num=1000)

# define the functions
def h(x):
    return x**5 - 2*x**4 + 2

def dh(x):
    return 5*x**4 - 8*x**3

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_f = dh,
                                                 initial_guess = -0.2,
                                                max_iteration=136)
# plot function, derivative and plot side by side
ppl.figure(figsize = [15,5])

# Cost function
ppl.subplot(1, 2, 1)

ppl.xlim(-1.2,2.5)
ppl.ylim(-1,4)

ppl.plot(X_3, h(X_3), color='blue', linewidth=2, alpha=0.5)
ppl.scatter(list_x, h(np.array(list_x)), color = 'red', s=60, alpha=0.5)



ppl.title('Cost function')
ppl.xlabel('X', fontsize = 12)
ppl.ylabel('h(x)', fontsize = 12)

# Derivative
ppl.subplot(1, 2, 2)
ppl.xlim(-1,2)
ppl.ylim(-4, 5)

ppl.plot(X_3, dh(X_3), color = 'blue', linewidth=2, alpha=0.5)
ppl.scatter(list_x, deriv_list, color='red', s=60, alpha=0.5)

ppl.title('Slope of the cost function')
ppl.xlabel('X', fontsize = 12)
ppl.ylabel('dh(x)', fontsize = 12)
ppl.grid()

ppl.show()


print('Local min at: ', local_min)
print('Cost at this point is: ', h(local_min))
print('Steps" ', len(list_x))
# Out:
# Local min at:  -4.885583793105108e+53
# Cost at this point is:  -2.783442996149689e+268
# Steps"  137

# %%
import sys
#help(sys)
#sys.version
# type(h(local_min))
# sys.float_info.max
